# %% [markdown]
# # Victor Calderon
#
# ## Analysis on the usage of Bike-riding programs in three major cities.
#
# This project focuses on analysing the impact that alternative methods of transportation have on the overall transit flux in different cities.
# The overarching goal of this project is to be able to apply this method to companies that are interested in investing less amount resources
# while still maximizing revenue. I am also interested in learning how these new transportation systems have affected the traffic congestion in
# general. For this project, I have performed a preliminary analysis on the usage of bike-riding programs at three major cities. I downloaded
# publicly available datasets from Bike-riding companies for three major cities, and computed different statistics to understand how these
# programs are being used at each city. With this information, I have determined the months, at which more bikes are needed at each city, as well
# as quantifying by how much the number of bike rides has increased throughout the years.
#
# This analysis can be tailored to the bike-riding industry, as well as other types of industries, such as scooters and other similar services.

# %% [markdown]
# # Data
#
# The data used for this analysis can be found at:
#
# - New York City - Bike-riding program: [https://www.citibikenyc.com/system-data](https://www.citibikenyc.com/system-data)
# - Washington, DC - Capital Bikeshare: [https://www.capitalbikeshare.com/system-data](https://www.capitalbikeshare.com/system-data)
# - San Francisco - Ford-Go Bike: [https://www.fordgobike.com/system-data](https://www.fordgobike.com/system-data)

# %% [markdown]
# # Main Analysis

# %% [markdown]
# ## Figure 1 - Number of bike rides taken every month
#
# For this figure, I extracted information about the date of different bike rides at three major cities, i.e. Washington D.C., San Francisco, and New York City.
# In here, I am averaging over all years for every month, and showing the result.
#
# This figure exhibits an interesting shape, in that most of the bike rides are taken in months of June-August, while not too many rides are taken in the Winter.

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
Image("../images/fig1.png")

# %% [markdown]
# ## Figure 2 - Increase in total number of bike rides per year
#
# For this figure, I computed the total number of bike rides per year at the three major cities.
# This plot shows that there has been an increase in the number of bike rides at each city, since these programs were started.
#
# This figure could be used to extrapolate the total number of bicycles needed at different locations.

# %%
Image("../images/fig2.png")

# %% [markdown]
# # Next steps
#  The next steps for this project would be to utilize geopositions of bycicles that tell you which stations are being used the most.
#  With this information, one could potentially target some of the major stations, and thus creating an increase in revenue.
